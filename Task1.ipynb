# %% [markdown]
# <a href="https://colab.research.google.com/github/KashiReddy31/BookStore/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
name="kashi Reddy"
height='5.9ft'
weight='65kg'
address='Hyderabad'
hobby='cricket'

# %%
print("My name is",name)
print("My height is",height)
print("My weight is",weight)
print("My address is",address)
print("My hobby is",hobby)
# Out:
# My name is kashi Reddy
# My height is 5.8ft
# My weight is 65kg
# My address is Hyderabad
# My hobby is cricket

# %%
print("My name is ",name + ", My height is " + height + ", My weight is " + weight + ", My address is " + address + ", My hobby is " + hobby)
# Out:
# My name is  kashi Reddy, My height is 5.8, My weight is 65kg, My address is Hyderabad, My hobby is cricket
