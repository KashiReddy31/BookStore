# %% [markdown]
# <a href="https://colab.research.google.com/github/KashiReddy31/BookStore/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.

age = 25
age += 10
print(age)
# Out:
# 35

# %%
# 2.

name = "kashi reddy"
print(len(name))
# Out:
# 11

# %%
# 3.

print(type(age))
print(isinstance(age, int))
# Out:
# <class 'int'>
# True

# %%
# 4.

age_str = str(age)
sentence = name + " is " + age_str + " years old."
print(sentence)
# Out:
# kashi reddy is 35 years old.

# %%
# 5.

height = 175.5
height = round(height)
print(height)
# Out:
# 176

# %%
# 6.

print(type(height))
height_int = int(height)
print(type(height_int))
# Out:
# <class 'int'>
# <class 'int'>

# %%
# 7.

is_student = True
if is_student: print("You are a student")
else: print("You are not a student")
# Out:
# You are a student

# %%
# 8.

print(type(is_student))
# Out:
# <class 'bool'>

# %%
# 9.

colors = ["red", "blue", "green", "yellow", "purple"]
print(colors[-1])
# Out:
# purple

# %%
# 10.

print(colors[1:4:2])
# Out:
# ['blue', 'yellow']

# %%
# 11.

dim = (10, 5, 3)
l, w, h = dim
print(l)
print(w)
print(h)
# Out:
# 10
# 5
# 3

# %%
# 12.

print(h)
# Out:
# 3

# %%
# 13.

person = {"name": "kashi", "age": 25, "city": "kadapa"}
person["profession"] = "data analyst"
print(person)
# Out:
# {'name': 'kashi', 'age': 25, 'city': 'kadapa', 'profession': 'data analyst'}

# %%
# 14.

print(person["age"])
person["age"] += 1
print(person["age"])
# Out:
# 27
# 28

# %%
# 15.

unique_numbers = {11, 21, 32, 42, 52}
print(len(unique_numbers))
# Out:
# 5

# %%
# 16.

unique_numbers.add(62)
print(unique_numbers)
unique_numbers.add(32)
print(unique_numbers)
# Out:
# {32, 52, 21, 42, 11, 62}
# {32, 52, 21, 42, 11, 62}

# %%
# 17.

x = 88
x_float = float(x)
print(x_float)
# Out:
# 88.0

# %%
# 18.

x += 5
print(x)
# Out:
# 98

# %%
# 19.

y = x ** 2
print(f"x: {x}, y: {y}")
# Out:
# x: 88, y: 7744

# %%
# 20.

x, y = y, x
print(f"After swapping: x: {x}, y: {y}")
# Out:
# After swapping: x: 7744, y: 88
